# %% [markdown]
# <a href="https://colab.research.google.com/github/BebekTerbang334/01-Array/blob/main/Soal_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3. Hitung rata-rata

# %%
nilai=[]
for i in range(10):
    angka = int(input("Masukkan Nilai Mahasiswa : "))
    nilai.append(angka)

print("Nilai Mahasiswa : ", nilai)
print("Nilai Tertinggi : ", max(nilai))
print("Nilai Terendah : ", min(nilai))
print("Nilai Rata-rata : ", sum(nilai)/len(nilai))
# Out:
# Masukkan Nilai Mahasiswa : 80
# Masukkan Nilai Mahasiswa : 59
# Masukkan Nilai Mahasiswa : 69
# Masukkan Nilai Mahasiswa : 39
# Masukkan Nilai Mahasiswa : 40
# Masukkan Nilai Mahasiswa : 59
# Masukkan Nilai Mahasiswa : 30
# Masukkan Nilai Mahasiswa : 59
# Masukkan Nilai Mahasiswa : 47
# Masukkan Nilai Mahasiswa : 49
# Nilai Mahasiswa: [80, 59, 69, 39, 40, 59, 30, 59, 47, 49]
# Nilai Tertinggi : 80
# Nilai Terendah : 30
# Nilai Rata-rata : 53.1
